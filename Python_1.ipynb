# %% [markdown]
# <a href="https://colab.research.google.com/github/yusangmin/python_report/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(1+2)
# Out:
# 3

# %%
print(2*3)
# Out:
# 6

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
a = 3; b = 4; c = a + b; print(c); print(a); print(b)
# Out:
# 7
# 3
# 4

# %%
a = "안녕하세요.";
b = "반갑습니다.";
c = a + b;
print(c)
# Out:
# 안녕하세요.반갑습니다.

# %%
a = "안녕하세요.";
b = a * 10;
print(b)
# Out:
# 안녕하세요.안녕하세요.안녕하세요.안녕하세요.안녕하세요.안녕하세요.안녕하세요.안녕하세요.안녕하세요.안녕하세요.

# %%
print("###############")
print("#" * 15)
# Out:
# ###############
# ###############

# %% [markdown]
# 아버지와 어머니 그리고 삼촌에게 감사한마음을 전하고 싶습니다.
# 아버지에는 10만원, 어머니에게는 15만원, 삼촌에게는 "감사합니다."
# 변수 : _Father, _Mother, _Uncle

# %%
_Father = "100,000"
_Mother = "150,000"
_Uncle = "감사합니다."
print("아버지=", _Father,"원")
print("어머니=", _Mother,"원")
print("삼촌=", _Uncle)
# Out:
# 아버지= 100,000 원
# 어머니= 150,000 원
# 삼촌= 감사합니다.

# %% [markdown]
# 변수의 규칙 : 문자 또는 _로 시작(Father, father, _father), 문자, 숫자, _구성(Father69, father55, father_56), 공백 절대안된다.안쓰는 것이 좋다. 특수문자 절대안된다.

# %% [markdown]
# FATHER, father, MOTHER, mother, _Father, _father,  Keyword (True, False, for, while, if, continue, break, class....)

# %% [markdown]
# 숫자자료형 = 숫자, 문자자료형 = 모든 문자들..

# %%
a= 2
b = "2"
c = a + int(b)
print(c)
# Out:
# 4

# %% [markdown]
# 형변환 : 정수형을 변환할때 int(), 실수형으로 변환하고자 할때float(), 문자자료형으로 변환하고자할때 str(), int(float("2.5"))

# %% [markdown]
# 산술연산자 : + 더하기(print(4+3), - 빼기(print(2-1), * 곱하기(print(5*4), / 나누기(print(4/2)), % 나머지 print(5 % 2), // 몫 print(6 // 2), ** 거듭제곱 pirnt(4**2)
